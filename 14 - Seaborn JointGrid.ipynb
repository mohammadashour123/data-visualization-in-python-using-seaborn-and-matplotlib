# %% [markdown]
# ![Screenshot%202022-06-18%20180045.png](attachment:Screenshot%202022-06-18%20180045.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180137.png](attachment:Screenshot%202022-06-18%20180137.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180158.png](attachment:Screenshot%202022-06-18%20180158.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180226.png](attachment:Screenshot%202022-06-18%20180226.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180245.png](attachment:Screenshot%202022-06-18%20180245.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180306.png](attachment:Screenshot%202022-06-18%20180306.png)

# %% [markdown]
# ![Screenshot%202022-06-18%20180333.png](attachment:Screenshot%202022-06-18%20180333.png)

# %% [markdown]
# # Seaborn: jointplot

# %%
import seaborn as sns

from matplotlib import pyplot as plt
import matplotlib

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
matplotlib.__version__
# Out:
# '3.3.4'

# %%
geyser = sns.load_dataset('geyser')

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
geyser.shape
# Out:
# (272, 3)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.jointplot(x=geyser.waiting, y=geyser.duration);

# %%
sns.jointplot(x='waiting', y='duration', data=geyser);

# %% [markdown]
# ## Plot Kinds
#
# There are currently six kinds of jointplots allowed in seaborn:
# 1. scatter (default)
# 2. kde
# 3. reg
# 4. hist
# 5. hex
# 6. resid

# %% [markdown]
# ### scatter (Default)

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='scatter'
             );

# %% [markdown]
# ### kde

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde'
             );

# %% [markdown]
# ### reg

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg'
             );

# %% [markdown]
# ### hist

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='hist'
             );

# %% [markdown]
# ### Returns JointGrid

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser);

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %% [markdown]
# ## Categorical Variables

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %% [markdown]
# ### hue

# %%
sns.jointplot(x='waiting', y='duration', data=geyser);

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind'
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind',
              kind='kde'
             );

# %% [markdown]
# ## Styling

# %% [markdown]
# ### color, palette

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              color='green'
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind',
              palette='autumn'
             );

# %% [markdown]
# ### height, space

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              height=18,   #Default: 6
              space=5,  #Default: 0.2
             );

# %% [markdown]
# ### joint_kws
#
# Joint keywords should match the figure type in the middle of the jointplot.

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              joint_kws={'marker': 5}
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg',
              joint_kws={'ci': None, 'order': 2}
             );

# %% [markdown]
# ### marginal_kws
#
# Marginal keywords should match the type of plot for the marginal distribution plots (the outside plots).

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              marginal_kws={'color': 'xkcd:golden'}
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde',
              marginal_kws={'lw': 4, 'shade': True}
             );
