# %% [markdown]
# # Seaborn: clustermap

# %% [markdown]
# ## Hierarchical Agglomerative Clustering

# %% [markdown]
# ![Screenshot%202022-06-11%20125220.png](attachment:Screenshot%202022-06-11%20125220.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125241.png](attachment:Screenshot%202022-06-11%20125241.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125256.png](attachment:Screenshot%202022-06-11%20125256.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125318.png](attachment:Screenshot%202022-06-11%20125318.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125333.png](attachment:Screenshot%202022-06-11%20125333.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125346.png](attachment:Screenshot%202022-06-11%20125346.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125407.png](attachment:Screenshot%202022-06-11%20125407.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125444.png](attachment:Screenshot%202022-06-11%20125444.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125457.png](attachment:Screenshot%202022-06-11%20125457.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125511.png](attachment:Screenshot%202022-06-11%20125511.png)

# %% [markdown]
# ![Screenshot%202022-06-11%20125525.png](attachment:Screenshot%202022-06-11%20125525.png)

# %%
import seaborn as sns

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basics - Toy Example

# %%
toy_data_dict = {
    'Name': ['Andy', 'Ben', 'Claire', 'David'],
    'Hours_Studied': [10, 20, 12, 28],
    'Score': [15, 20, 16, 25],
    'Street_Address': [11, 24, 18, 9]
}

# %%
toy_data = pd.DataFrame(toy_data_dict)
toy_data.set_index('Name', inplace=True)

toy_data
# Out:
#         Hours_Studied  Score  Street_Address
# Name
# Andy               10     15              11
# Ben                20     20              24
# Claire             12     16              18
# David              28     25               9

# %%
sns.clustermap(toy_data, figsize=(8, 4), annot=True);

# %% [markdown]
# ## Basics - Penguins Dataset

# %% [markdown]
# #### Load the data

# %%
penguins = sns.load_dataset('penguins').dropna()

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
penguins.shape
# Out:
# (333, 7)

# %% [markdown]
# #### Build clustermap

# %%
numerical_cols = penguins.columns[2:6]

numerical_cols
# Out:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'], dtype='object')

# %%
sns.clustermap(penguins[numerical_cols]);

# %% [markdown]
# #### `standard_scale`

# %%
sns.clustermap(penguins[numerical_cols], standard_scale=1);

# %% [markdown]
# ## Additional Options

# %% [markdown]
# ### `row_colors`

# %%
species_colors=penguins.species.map({
    'Adelie': 'blue',
    'Chinstrap': 'red',
    'Gentoo': 'green'
})

# %%
len(species_colors)
# Out:
# 333

# %%
species_colors[:5]
# Out:
# 0    blue
# 1    blue
# 2    blue
# 4    blue
# 5    blue
# Name: species, dtype: object

# %%
sns.clustermap(penguins[numerical_cols], standard_scale=1, row_colors=species_colors);

# %% [markdown]
# ## BONUS: Styling

# %% [markdown]
# #### `cmap` and `vmin`

# %%
sns.clustermap(toy_data, figsize=(5, 5), cmap='Blues', vmin=5);

# %% [markdown]
# #### `row_cluster` and `cbar_pos`

# %%
sns.clustermap(toy_data, figsize=(5, 5), cmap='Blues', vmin=5,
               row_cluster=False,
               cbar_pos=None #(0,.4,.05,.35)
              );

# %% [markdown]
# #### Annotations with `annot` and `fmt`

# %%
sns.clustermap(toy_data, figsize=(5, 5), cmap='Blues', vmin=5, annot=True, fmt='.0f');
